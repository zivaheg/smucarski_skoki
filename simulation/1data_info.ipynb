# %% [markdown]
# importamo en file

# %%
import pandas as pd

df = pd.read_csv("2024_03_Planica_12_winds/999_999_Jumper_Anon_ANO_1_20240409-103100_C_OfficialResults.csv", sep=';', decimal=',')

# %% [markdown]
# ## Priprava podatkov

# %%
TAB1 = df
TAB1
# Out:
#     Position Height above ground [m]                               Time  \
# 0     -92.27                     NaN  0001-01-01T00:00:00.0000000+01:00
# 1       0.00                    2.93  0001-01-01T00:00:04.1350000+01:00
# 2       1.00                    2.92  0001-01-01T00:00:04.2640000+01:00
# 3       2.00                    2.93  0001-01-01T00:00:04.3620000+01:00
# 4       3.00                    2.96  0001-01-01T00:00:04.4010000+01:00
# ..       ...                     ...                                ...
# 115   114.00                    0.46  0001-01-01T00:00:08.4710000+01:00
# 116   115.00                    0.35  0001-01-01T00:00:08.5050000+01:00
# 117   116.00                    0.23  0001-01-01T00:00:08.5370000+01:00
# 118   117.00                    0.08  0001-01-01T00:00:08.5700000+01:00
# 119   117.50                    0.00  0001-01-01T00:00:08.5870000+01:00
#
#       X [m]  Y [m]   Z [m] Opening Angle [°] Stalling Angle Left [°]  \
# 0    -80.31   0.00   42.22               NaN                     NaN
# 1      0.01   0.00   -0.00               0.0                 -11.500
# 2      1.23  -0.01   -0.16               1.5                  -8.217
# 3      2.38  -0.02   -0.30               3.1                  -4.056
# 4      3.42  -0.03   -0.43               4.6                   1.818
# ..      ...    ...     ...               ...                     ...
# 115  102.04  -3.91  -51.83               5.9                 -16.828
# 116  102.80  -3.97  -52.48               4.9                 -21.040
# 117  103.55  -4.01  -53.14               3.5                 -25.045
# 118  104.30  -4.07  -53.80               1.7                 -29.255
# 119  104.67  -4.10  -54.13               0.8                 -31.424
#
#     Stalling Angle Right [°] Roll Angle Left [°] Roll Angle Right [°]  \
# 0                        NaN                 NaN                  NaN
# 1                    -11.500               0.000                0.000
# 2                     -9.361               3.053                1.294
# 3                     -6.269               5.158                2.286
# 4                     -1.270               5.426                2.700
# ..                       ...                 ...                  ...
# 115                  -12.635              -5.685                0.935
# 116                  -15.638              -4.523               -0.088
# 117                  -21.007              -3.417                0.096
# 118                  -26.580              -2.931                0.287
# 119                  -29.429              -2.878                0.385
#
#     Yaw Angle Left [°] Yaw Angle Right [°] Speed hor. [km/h]  \
# 0                  NaN                 NaN             0.000
# 1                0.000               0.000            96.056
# 2                0.612              -0.929            96.065
# 3                1.210              -1.866            96.299
# 4                1.806              -2.832            96.884
# ..                 ...                 ...               ...
# 115             -4.645             -10.265            82.024
# 116             -5.378              -9.282            81.384
# 117             -6.074              -8.153            81.747
# 118             -6.144              -6.982            82.119
# 119             -5.986              -6.383            82.307
#
#     Speed vert. [km/h] Speed resulting [km/h]  \
# 0                0.000                  0.000
# 1              -19.543                 98.024
# 2              -14.128                 97.100
# 3              -10.486                 96.873
# 4              -10.357                 97.441
# ..                 ...                    ...
# 115            -70.178                108.164
# 116            -71.328                108.403
# 117            -70.766                108.293
# 118            -69.042                107.459
# 119            -67.823                106.830
#
#     WindTime|WindName|WindSpeed|WindSpeedTangent|WindTurbulence|WindSpeedCleanTan|WindSpeedCross
# 0    0001-01-01T00:00:00.038+01:00|W1|1.5|1.40|0.26...
# 1    0001-01-01T00:00:04.035+01:00|W1|1.6|1.42|0.07...
# 2    0001-01-01T00:00:04.286+01:00|W1|1.6|1.42|0.07...
# 3    0001-01-01T00:00:04.286+01:00|W1|1.6|1.42|0.07...
# 4    0001-01-01T00:00:04.286+01:00|W1|1.6|1.42|0.07...
# ..                                                 ...
# 115  0001-01-01T00:00:08.541+01:00|W1|1.8|1.61|0.17...
# 116  0001-01-01T00:00:08.541+01:00|W1|1.8|1.61|0.17...
# 117  0001-01-01T00:00:08.541+01:00|W1|1.8|1.61|0.17...
# 118  0001-01-01T00:00:08.541+01:00|W1|1.8|1.61|0.17...
# 119  0001-01-01T00:00:08.541+01:00|W1|1.8|1.61|0.17...
#
# [120 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Position', 'Height above ground [m]', 'Time', 'X [m]', 'Y [m]',
#        'Z [m]', 'Opening Angle [°]', 'Stalling Angle Left [°]',
#        'Stalling Angle Right [°]', 'Roll Angle Left [°]',
#        'Roll Angle Right [°]', 'Yaw Angle Left [°]', 'Yaw Angle Right [°]',
#        'Speed hor. [km/h]', 'Speed vert. [km/h]', 'Speed resulting [km/h]',
#        'WindTime|WindName|WindSpeed|WindSpeedTangent|WindTurbulence|WindSpeedCleanTan|WindSpeedCross'],
#       dtype='object')

# %% [markdown]
# izločimo najbolj problematičen stolpec

# %%
wind_col_name = df.columns[-1]
print("Last column:", wind_col_name)
print("Example value:", df[wind_col_name].iloc[0])
# Out:
# Last column: WindTime|WindName|WindSpeed|WindSpeedTangent|WindTurbulence|WindSpeedCleanTan|WindSpeedCross
# Example value: 0001-01-01T00:00:00.038+01:00|W1|1.5|1.40|0.26|1.40|0.08;0001-01-01T00:00:00.038+01:00|W2|1.6|1.45|0.11|1.45|0.33;0001-01-01T00:00:00.038+01:00|W3|1.2|1.16|0.08|1.16|0.07;0001-01-01T00:00:00.038+01:00|W4|1.3|1.23|0.22|1.23|0.21;0001-01-01T00:00:00.038+01:00|W5|1.6|1.53|0.21|1.53|0.12;0001-01-01T00:00:00.038+01:00|W6|1.8|1.45|0.05|1.45|1.07;0001-01-01T00:00:00.038+01:00|W7|2.2|2.13|0.05|2.13|0.34;0001-01-01T00:00:00.038+01:00|W8|2.6|2.58|0.19|2.58|0.31;0001-01-01T00:00:00.038+01:00|W9|2.3|2.22|0.24|2.22|0.76;0001-01-01T00:00:00.038+01:00|W10|1.8|1.77|0.09|1.77|0.30;0001-01-01T00:00:00.038+01:00|W11|2.1|0.90|0.27|0.90|1.88;0001-01-01T00:00:00.038+01:00|W12|1.4|1.31|0.15|1.31|0.18

# %% [markdown]
# izluščimo podatke o vetru

# %%
from flatten_wind import *

wind_df = df[wind_col_name].apply(flatten_wind_blob)
df_cleaned = pd.concat([df.drop(columns=[wind_col_name]), wind_df], axis=1)

print(df_cleaned.head())
# Out:
#   Position Height above ground [m]                               Time   X [m]  \
# 0   -92.27                     NaN  0001-01-01T00:00:00.0000000+01:00  -80.31
# 1     0.00                    2.93  0001-01-01T00:00:04.1350000+01:00    0.01
# 2     1.00                    2.92  0001-01-01T00:00:04.2640000+01:00    1.23
# 3     2.00                    2.93  0001-01-01T00:00:04.3620000+01:00    2.38
# 4     3.00                    2.96  0001-01-01T00:00:04.4010000+01:00    3.42
#
#    Y [m]  Z [m] Opening Angle [°] Stalling Angle Left [°]  \
# 0   0.00  42.22               NaN                     NaN
# 1   0.00  -0.00               0.0                 -11.500
# 2  -0.01  -0.16               1.5                  -8.217
# 3  -0.02  -0.30               3.1                  -4.056
# 4  -0.03  -0.43               4.6                   1.818
#
#   Stalling Angle Right [°] Roll Angle Left [°]  ... W11_Speed W11_Tangent  \
# 0                      NaN                 NaN  ...       2.1        0.90
# 1                  -11.500               0.000  ...       2.1        0.97
# 2                   -9.361               3.053  ...       2.1        0.97
# 3                   -6.269               5.158  ...       2.1        0.97
# 4                   -1.270               5.426  ...       2.1        0.97
#
#   W11_Turbulence W11_CleanTan W11_Cross W12_Speed  W12_Tangent  \
# 0           0.27         0.90      1.88       1.4         1.31
# 1           0.07         0.97      1.88       1.4         1.19
# 2           0.07         0.97      1.88       1.4         1.19
# 3           0.07         0.97      1.88       1.4         1.19
# 4           0.07         0.97      1.88       1.4         1.19
#
#    W12_Turbulence  W12_CleanTan  W12_Cross
# 0            0.15          1.31       0.18
# 1            0.13          1.19       0.04
# 2            0.13          1.19       0.04
# 3            0.13          1.19       0.04
# 4            0.13          1.19       0.04
#
# [5 rows x 76 columns]

# %% [markdown]
# izluščimo podatke o času

# %%
df_cleaned["Time"] = df_cleaned["Time"].apply(timestamp_to_seconds)

# %%
TAB2 = df_cleaned
TAB2
# Out:
#     Position Height above ground [m]   Time   X [m]  Y [m]   Z [m]  \
# 0     -92.27                     NaN  0.000  -80.31   0.00   42.22
# 1       0.00                    2.93  4.135    0.01   0.00   -0.00
# 2       1.00                    2.92  4.264    1.23  -0.01   -0.16
# 3       2.00                    2.93  4.362    2.38  -0.02   -0.30
# 4       3.00                    2.96  4.401    3.42  -0.03   -0.43
# ..       ...                     ...    ...     ...    ...     ...
# 115   114.00                    0.46  8.471  102.04  -3.91  -51.83
# 116   115.00                    0.35  8.505  102.80  -3.97  -52.48
# 117   116.00                    0.23  8.537  103.55  -4.01  -53.14
# 118   117.00                    0.08  8.570  104.30  -4.07  -53.80
# 119   117.50                    0.00  8.587  104.67  -4.10  -54.13
#
#     Opening Angle [°] Stalling Angle Left [°] Stalling Angle Right [°]  \
# 0                 NaN                     NaN                      NaN
# 1                 0.0                 -11.500                  -11.500
# 2                 1.5                  -8.217                   -9.361
# 3                 3.1                  -4.056                   -6.269
# 4                 4.6                   1.818                   -1.270
# ..                ...                     ...                      ...
# 115               5.9                 -16.828                  -12.635
# 116               4.9                 -21.040                  -15.638
# 117               3.5                 -25.045                  -21.007
# 118               1.7                 -29.255                  -26.580
# 119               0.8                 -31.424                  -29.429
#
#     Roll Angle Left [°]  ... W11_Speed W11_Tangent W11_Turbulence  \
# 0                   NaN  ...       2.1        0.90           0.27
# 1                 0.000  ...       2.1        0.97           0.07
# 2                 3.053  ...       2.1        0.97           0.07
# 3                 5.158  ...       2.1        0.97           0.07
# 4                 5.426  ...       2.1        0.97           0.07
# ..                  ...  ...       ...         ...            ...
# 115              -5.685  ...       2.1        1.07           0.01
# 116              -4.523  ...       2.1        1.07           0.01
# 117              -3.417  ...       2.1        1.07           0.01
# 118              -2.931  ...       2.1        1.07           0.01
# 119              -2.878  ...       2.1        1.07           0.01
#
#     W11_CleanTan W11_Cross W12_Speed  W12_Tangent  W12_Turbulence  \
# 0           0.90      1.88       1.4         1.31            0.15
# 1           0.97      1.88       1.4         1.19            0.13
# 2           0.97      1.88       1.4         1.19            0.13
# 3           0.97      1.88       1.4         1.19            0.13
# 4           0.97      1.88       1.4         1.19            0.13
# ..           ...       ...       ...          ...             ...
# 115         1.07      1.82       1.3         1.14            0.12
# 116         1.07      1.82       1.3         1.14            0.12
# 117         1.07      1.82       1.3         1.14            0.12
# 118         1.07      1.82       1.3         1.14            0.12
# 119         1.07      1.82       1.3         1.14            0.12
#
#      W12_CleanTan  W12_Cross
# 0            1.31       0.18
# 1            1.19       0.04
# 2            1.19       0.04
# 3            1.19       0.04
# 4            1.19       0.04
# ..            ...        ...
# 115          1.14       0.55
# 116          1.14       0.55
# 117          1.14       0.55
# 118          1.14       0.55
# 119          1.14       0.55
#
# [120 rows x 76 columns]

# %% [markdown]
# ## Analiza

# %%
razpon_visine = f"od {TAB2["Height above ground [m]"].dropna().min()} do {TAB2["Height above ground [m]"].dropna().max()}"
razpon_visine
# Out:
# 'od 0.00 do 5.01'

# %%
differences = {}

for idx in range(len(df_cleaned["Time"]) - 1):
    a = df_cleaned["Time"].iloc[idx + 1]
    b = df_cleaned["Time"].iloc[idx]
    r = a - b
    differences[idx] = r

razpon_casa = f"od {min(differences.values())} do {max(differences.values())}"
razpon_casa

#alternativna verzija:
#time_diffs = df_cleaned["Time"].diff().dropna()
#razpon_casa = f"od {time_diffs.min()} do {time_diffs.max()}"
#razpon_casa
# Out:
# 'od 0.01699999999999946 do 4.135'

# %% [markdown]
# pri nekaterih files dobimo negativno vrednost, zato preverimo stolpec časov

# %%
is_sorted = df_cleaned["Time"].is_monotonic_increasing
print("Is time column sorted?", is_sorted)
# Out:
# Is time column sorted? True

# %%
# Print first few values
print(df_cleaned["Time"].head(10))
# Out:
# 0    0.000
# 1    4.135
# 2    4.264
# 3    4.362
# 4    4.401
# 5    4.440
# 6    4.479
# 7    4.518
# 8    4.557
# 9    4.596
# Name: Time, dtype: float64

# %%
TAB2
# Out:
#     Position Height above ground [m]   Time   X [m]  Y [m]   Z [m]  \
# 0     -92.27                     NaN  0.000  -80.31   0.00   42.22
# 1       0.00                    2.93  4.135    0.01   0.00   -0.00
# 2       1.00                    2.92  4.264    1.23  -0.01   -0.16
# 3       2.00                    2.93  4.362    2.38  -0.02   -0.30
# 4       3.00                    2.96  4.401    3.42  -0.03   -0.43
# ..       ...                     ...    ...     ...    ...     ...
# 115   114.00                    0.46  8.471  102.04  -3.91  -51.83
# 116   115.00                    0.35  8.505  102.80  -3.97  -52.48
# 117   116.00                    0.23  8.537  103.55  -4.01  -53.14
# 118   117.00                    0.08  8.570  104.30  -4.07  -53.80
# 119   117.50                    0.00  8.587  104.67  -4.10  -54.13
#
#     Opening Angle [°] Stalling Angle Left [°] Stalling Angle Right [°]  \
# 0                 NaN                     NaN                      NaN
# 1                 0.0                 -11.500                  -11.500
# 2                 1.5                  -8.217                   -9.361
# 3                 3.1                  -4.056                   -6.269
# 4                 4.6                   1.818                   -1.270
# ..                ...                     ...                      ...
# 115               5.9                 -16.828                  -12.635
# 116               4.9                 -21.040                  -15.638
# 117               3.5                 -25.045                  -21.007
# 118               1.7                 -29.255                  -26.580
# 119               0.8                 -31.424                  -29.429
#
#     Roll Angle Left [°]  ... W11_Speed W11_Tangent W11_Turbulence  \
# 0                   NaN  ...       2.1        0.90           0.27
# 1                 0.000  ...       2.1        0.97           0.07
# 2                 3.053  ...       2.1        0.97           0.07
# 3                 5.158  ...       2.1        0.97           0.07
# 4                 5.426  ...       2.1        0.97           0.07
# ..                  ...  ...       ...         ...            ...
# 115              -5.685  ...       2.1        1.07           0.01
# 116              -4.523  ...       2.1        1.07           0.01
# 117              -3.417  ...       2.1        1.07           0.01
# 118              -2.931  ...       2.1        1.07           0.01
# 119              -2.878  ...       2.1        1.07           0.01
#
#     W11_CleanTan W11_Cross W12_Speed  W12_Tangent  W12_Turbulence  \
# 0           0.90      1.88       1.4         1.31            0.15
# 1           0.97      1.88       1.4         1.19            0.13
# 2           0.97      1.88       1.4         1.19            0.13
# 3           0.97      1.88       1.4         1.19            0.13
# 4           0.97      1.88       1.4         1.19            0.13
# ..           ...       ...       ...          ...             ...
# 115         1.07      1.82       1.3         1.14            0.12
# 116         1.07      1.82       1.3         1.14            0.12
# 117         1.07      1.82       1.3         1.14            0.12
# 118         1.07      1.82       1.3         1.14            0.12
# 119         1.07      1.82       1.3         1.14            0.12
#
#      W12_CleanTan  W12_Cross
# 0            1.31       0.18
# 1            1.19       0.04
# 2            1.19       0.04
# 3            1.19       0.04
# 4            1.19       0.04
# ..            ...        ...
# 115          1.14       0.55
# 116          1.14       0.55
# 117          1.14       0.55
# 118          1.14       0.55
# 119          1.14       0.55
#
# [120 rows x 76 columns]

# %% [markdown]
# ## vizualizacija

# %% [markdown]
# ### veter
# Veter je merjen z 12 senzorji (W1-W12) razporejeni na 3 različne cone po skakalnici.

# %%
zones = {
    "takeoff": ["W1_Tangent", "W2_Tangent", "W3_Tangent"],
    "mid":     ["W4_Tangent", "W5_Tangent", "W6_Tangent", "W7_Tangent"],
    "landing": ["W8_Tangent", "W9_Tangent", "W10_Tangent", "W11_Tangent", "W12_Tangent"]
}

# %% [markdown]
# naredimo slovar cone in njenega povprečnega vetra v tej coni

# %%
zone_winds = {
    zone: df_cleaned[cols].astype(float).mean(axis=1).mean()
    for zone, cols in zones.items()
}

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# določimo koordinate
x_data = df_cleaned["X [m]"][1:].astype(float).to_numpy()
y_data = df_cleaned["Y [m]"][1:].astype(float).to_numpy()
z_data = df_cleaned["Z [m]"][1:].astype(float).to_numpy()
#x = np.insert(x_data, 0, 0.0)
#y = np.insert(y_data, 0, 0.0)
#z = np.insert(z_data, 0, 0.0)


#približne lokacije za puščice vetra
n = len(x)
positions = {
    "takeoff": int(n * 0.15),
    "mid":     int(n * 0.5),
    "landing": int(n * 0.85)
}

# plot flight trajectory
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot3D(x, y, z, label='Ski Jump Trajectory', color='blue', linewidth=2)
ax.scatter3D(x, y, z, color='red', s=10, alpha=0.6)

# Plot wind arrows (tangent direction = along X)

for zone, position in positions.items():
    wind = zone_winds[zone]
    ax.quiver(x[position], z[position], y[position],
              1 if wind >= 0 else -1, 0, 0,  # X-direction only
              length=abs(wind) * 3, color='green', linewidth=2,
              label=f'{zone} wind: {wind:.2f} m/s')


ax.set_title("3D Flight with Wind Profiles")
ax.set_xlabel("X [m] (length)")
ax.set_ylabel("Y [m] (width)")
ax.set_zlabel("Z [m] (height)")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Nakateri Y zavzammejo pozitivne vrednosti, poskusimo če sprmenimo.

# %% [markdown]
# ##### path

# %%
df_cleaned["Y [m]"] = df_cleaned["Y [m]"].astype(float)

# Now safely check and flip if needed
if df_cleaned["Y [m]"].iloc[-1] >= 0:
    df_cleaned["Y [m]"] = -df_cleaned["Y [m]"]
    print("Y column was flipped (now ends with a negative value).")
else:
    print("Y column already ends with a negative value, no change made.")
# Out:
# Y column already ends with a negative value, no change made.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# koordinate z začetkom v (0, 0, 0)
x_data = df_cleaned["X [m]"][1:].astype(float).to_numpy()
y_data = df_cleaned["Y [m]"][1:].astype(float).to_numpy()
z_data = df_cleaned["Z [m]"][1:].astype(float).to_numpy()
#x = np.insert(x_data, 0, 0.0)
#y = np.insert(y_data, 0, 0.0)
#z = np.insert(z_data, 0, 0.0)

# Plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.plot3D(x, y, z, label='Ski Jump Trajectory', color='blue', linewidth=2)
ax.scatter3D(x, y, z, color='red', s=10, alpha=0.6)

ax.set_ylim(-5, 5)
ax.set_title("3D Flight 102833 Trajectory")
ax.set_xlabel("X [m] (length)")
ax.set_ylabel("Y [m] (width)")
ax.set_zlabel("Z [m] (height)")
ax.legend()
plt.tight_layout()
plt.show()
