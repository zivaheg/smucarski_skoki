# %%
zones = {
    "takeoff": ["W1", "W2", "W3", "W4"],
    "mid":     ["W5", "W6", "W7", "W8"],
    "landing": ["W9", "W10", "W11", "W12"]
}

wind_features = ["Speed", "Tangent", "Cross", "Turbulence"]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math

def plot(X_seq, X_sim, j, name, error):
    """
    Plot actual vs simulated trajectory in 3D with projections.
    Args:
        X_seq (ndarray): ground truth state sequence (T, state_dim)
        X_sim (ndarray): simulated state sequence (T, state_dim)
        j (int): index of jump
        name (str): identifier for saving plots """

    save_dir = f"plots/{name}"
    os.makedirs(save_dir, exist_ok=True)

    
    actual = X_seq[:, :3]   #vzame X,Y,Z iz [x, y, z, vx, vy, vz]
    sim = X_sim[:, :3]          # same iz simulacije

    Xa, Ya, Za = actual[:,0], actual[:,1], actual[:,2]
    Xs, Ys, Zs = sim[:,0], sim[:,1], sim[:,2]

    #napaka = np.mean(error_fun(actual, sim))
    napaka = error
    length = (Xs[-1]**2 + Ys[-1]**2 + Zs[-1]**2)**(1/2)
    length_a = (Xa[-1]**2 + Ya[-1]**2 + Za[-1]**2)**(1/2)

    fig = plt.figure(figsize=(8, 5))
    ax = fig.add_subplot(111, projection='3d')

    ax.plot3D(Xa, Ya, Za, label="Actual", color="blue")
    ax.plot3D(Xs, Ys, Zs, label="Simulated", color="red", linestyle="--")


    # Ground projections
    ax.plot(Xa, 15, Za, color="blue", alpha=0.3, linestyle=':')
    ax.plot(Xs, 15, Zs, color="red", alpha=0.3, linestyle=':')

    ax.plot(0, Ya, Za, color="blue", alpha=0.3, linestyle=':')
    ax.plot(0, Ys, Zs, color="red", alpha=0.3, linestyle=':')


    ax.set_title(f"Actual vs Simulated Trajectory\n Error: {napaka:.3f}, Simulated length: {length:.1f},  Actual length: {length_a:.1f}")
    ax.set_xlabel("X [m]")
    ax.set_ylabel("Y [m]")
    ax.set_zlabel("Z [m]")
    ax.legend()
    ax.set_box_aspect([1,1,1])
    ax.set_ylim(-30, 30)

    plt.legend()
    #plt.tight_layout()

    filename = f"2SSM flight_simulation{j + 1}.png"
    plt.savefig(os.path.join(save_dir, filename), dpi=300)
    plt.close(fig)
    #plt.show()

# %% [markdown]
# ### old functions

# %%
import numpy as np
from scipy.interpolate import interp1d

def resample_curve(curve, n_points=200):
    """
    Resample a 3D curve to have exactly n_points, parameterized by arc length.

    Args:
        curve: (N, d) array, trajectory points
        n_points: number of resampled points

    Returns:
        (n_points, d) array, resampled curve
    """
    # compute arc length
    diffs = np.diff(curve, axis=0)
    seg_lengths = np.linalg.norm(diffs, axis=1)
    arc = np.concatenate([[0], np.cumsum(seg_lengths)])

    # normalize arc length to [0, 1]
    arc_norm = arc / arc[-1]

    # create interpolators
    resampled = []
    t_new = np.linspace(0, 1, n_points)
    for d in range(curve.shape[1]):
        f = interp1d(arc_norm, curve[:, d], kind="linear")
        resampled.append(f(t_new))
    return np.stack(resampled, axis=1)

# %%
def curve_error_with_overshoot(curve_a, curve_b, n_points=200):
    # resample both
    len_a = len(curve_a)
    len_b = len(curve_b)

    n_common = min(len_a, len_b)
    a_res = resample_curve(curve_a, n_common)
    b_res = resample_curve(curve_b, n_common)

    # pointwise error on common part
    errors = list(np.linalg.norm(a_res - b_res, axis=1))

    # overshoot penalty
    if len_a > len_b:
        last_b = curve_b[-1]
        extra = curve_a[len_b:]
        for p in extra:
            errors.append(np.linalg.norm(p - last_b))
    elif len_b > len_a:
        last_a = curve_a[-1]
        extra = curve_b[len_a:]
        for p in extra:
            errors.append(np.linalg.norm(p - last_a))

    return np.mean(errors), np.array(errors)

# %% [markdown]
# ### new funtions

# %%
def interpolate_curve_by_x(curve):
    """
    Interpolates a 3D curve by x-coordinate and returns (x, y, z),
    keeping the original start and end points exactly.

    Args:
        curve : array-like of shape (N, 3)
            Each row is [x, y, z].

    Returns:
        result : ndarray of shape (M, 3)
            Interpolated coordinates at integer x plus original endpoints.
    """

    curve = np.asarray(curve, dtype=float)
    if curve.ndim != 2 or curve.shape[1] != 3:  #uneccessary
        raise ValueError("sth")

    curve = curve[np.argsort(curve[:, 0])]

    x = curve[:, 0]
    y = curve[:, 1]
    z = curve[:, 2]    

    x_new = np.arange(np.ceil(x.min()) + 0, np.floor(x.max()) + 1)

    f_y = interp1d(x, y, kind="linear", bounds_error=False, fill_value="extrapolate")
    f_z = interp1d(x, z, kind="linear", bounds_error=False, fill_value="extrapolate")

    if len(x_new) > 0:
        y_new = f_y(x_new)
        z_new = f_z(x_new)
        result = np.vstack([
            curve[0],
            np.column_stack((x_new, y_new, z_new)),
            curve[-1]
        ])
    else:
        result = curve

    return result

# %%
def error_fun(curveA, curveB):
    curve1 = interpolate_curve_by_x(curveA)
    curve2 = interpolate_curve_by_x(curveB)

    if len(curve1) < len(curve2):
        longer = curve2
        shorter = curve1
    else:
        longer = curve1
        shorter = curve2

    longer1 = longer[:len(shorter)]
    shorter1 = shorter

    pad_len = len(longer) - len(shorter)
    if pad_len > 0:
        pad = np.repeat(shorter[-1][None, :], pad_len, axis=0)
        shorter2 = pad
        longer2 = longer[len(shorter):]

        diffs = np.vstack([longer1 - shorter1, longer2 - shorter2])
    else:
        diffs = longer1 - shorter1

    dists = np.linalg.norm(diffs, axis=1)
    return np.mean(dists)

# %%
def preprocess_flight_normalized(df, step=0.05):
    """
    Preprocess a normalized flight dataframe (already interpolated) to generate states (X), observations (Y), and controls (U).
    
    Args:
        df (pd.DataFrame): Normalized flight dataframe (fixed time step).
        step (float): Time step between rows (used for derivatives).
        
    Returns:
        states (np.ndarray): State matrix [time_steps, state_dim].
        observations (np.ndarray): Observation matrix [time_steps, obs_dim].
        controls (np.ndarray): Control matrix [time_steps, control_dim].
    """

    df.columns = df.columns.str.strip()   #izloči imena stolpcev
    df = df.iloc[1:]
    
    df = df.ffill().bfill()   #back fill za manjkajoče vrednosti
    
    x = df["X [m]"].to_numpy()   #save values
    y = df["Y [m]"].to_numpy()
    z = df["Z [m]"].to_numpy()
    
    dt = step
    #vx = np.gradient(x, dt)   #gradient za hitrost
    vx = df.get("Speed hor. [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)
    vy = np.gradient(y, dt)
    #vz = np.gradient(z, dt)
    vz = df.get("Speed ver. [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)

    speed = df.get("speed resulting [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)

    opening = df.get("Opening Angle [°]", pd.Series([0]*len(x))).to_numpy()
    roll_L = df.get("Roll Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    roll_R = df.get("Roll Angle Right [°]", pd.Series([0]*len(x))).to_numpy()
    yaw_L = df.get("Yaw Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    yaw_R = df.get("Yaw Angle Right [°]", pd.Series([0]*len(x))).to_numpy()
    stall_L = df.get("Stalling Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    stall_R = df.get("Stalling Angle Right [°]", pd.Series([0]*len(x))).to_numpy()

    states = np.stack([x, y, z, vx, vy, vz, speed, opening, roll_L, roll_R, yaw_L, yaw_R, stall_L, stall_R], axis=1)   #zgradimo state vector X

    height = df.get("Height above ground [m]", pd.Series([0]*len(x))).to_numpy()

    observations = np.stack([x, y, z, height], axis=1)   #zgradimo observation vector Y

    zone_feature_avgs = []
    values = []
    cols = []

    #    #all features
    #for feature in wind_features:
    #    for sensor_numb in range(12):
    #        sensor = f"W{sensor_numb + 1}"
    #        cols.append(f"{sensor}_{feature}")
    #        #print(cols)
    #for col in cols:
    #    val = df.get(col, pd.Series([0]*len(x))).to_numpy() 
    #    values.append(val)
    #
    #controls = np.stack(values, axis=1) 

    #    #zone
    #for feature in wind_features:
    #    for zone, sensors in zones.items():
    #        cols = [f"{sensor}_{feature}" for sensor in sensors if f"{sensor}_{feature}" in df.columns]
    #        avg_feature = df[cols].mean(axis=1).to_numpy()
    #        zone_feature_avgs.append(avg_feature)
    #
    #controls = np.stack(zone_feature_avgs, axis=1)

    for feature in wind_features:
        for zone, sensors in zones.items():
            cols = [f"{sensor}_{feature}" for sensor in sensors if f"{sensor}_{feature}" in df.columns]
            avg_feature = df[cols].mean(axis=1).to_numpy()
            zone_feature_avgs.append(avg_feature)
            angles = [speed, opening, roll_L, roll_R, yaw_L, yaw_R, stall_L, stall_R]
    for feat in angles:
        zone_feature_avgs.append(feat)
    
    controls = np.stack(zone_feature_avgs, axis=1)
    
    return states, observations, controls

# %%
import os
import pandas as pd
import numpy as np

normalized_folder = r'C:\Users\vsi\Desktop\ijs\smucarski_skoki\project\simulation\2024_03_Planica_12_winds\cleaned\normalized'
combined_output = os.path.join(normalized_folder, "combined_dataset.npz")
file_names = []

X_list, Y_list, U_list = [], [], []

for filename in os.listdir(normalized_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(normalized_folder, filename)
        df = pd.read_csv(file_path)

        X_state, Y_obs, U_ctrl = preprocess_flight_normalized(df)

        X_list.append(X_state)
        Y_list.append(Y_obs)
        U_list.append(U_ctrl)
        file_names.append(filename)

        #if np.any(np.isnan(X_state)):
        #    print(f"NaN values in {filename}")

        print(f"Processed {filename} -> X:{X_state.shape}, Y:{Y_obs.shape}, U:{U_ctrl.shape}")

# Save combined dataset
#np.savez(combined_output, X=np.array(X_list, dtype=object), Y=np.array(Y_list, dtype=object), U=np.array(U_list, dtype=object))
print(f"\nCombined dataset saved to {combined_output}")
# Out:
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102625_C_OfficialResults_cleaned_normalized.csv -> X:(135, 14), Y:(135, 4), U:(135, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102742_C_OfficialResults_cleaned_normalized.csv -> X:(131, 14), Y:(131, 4), U:(131, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102831_C_OfficialResults_cleaned_normalized.csv -> X:(145, 14), Y:(145, 4), U:(145, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102832_C_OfficialResults_cleaned_normalized.csv -> X:(139, 14), Y:(139, 4), U:(139, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102833_C_OfficialResults_cleaned_normalized.csv -> X:(136, 14), Y:(136, 4), U:(136, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102834_C_OfficialResults_cleaned_normalized.csv -> X:(132, 14), Y:(132, 4), U:(132, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102835_C_OfficialResults_cleaned_normalized.csv -> X:(156, 14), Y:(156, 4), U:(156, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102836_C_OfficialResults_cleaned_normalized.csv -> X:(134, 14), Y:(134, 4), U:(134, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102837_C_OfficialResults_cleaned_normalized.csv -> X:(124, 14), Y:(124, 4), U:(124, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102838_C_OfficialResults_cleaned_normalized.csv -> X:(131, 14), Y:(131, 4), U:(131, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102839_C_OfficialResults_cleaned_normalized.csv -> X:(146, 14), Y:(146, 4), U:(146, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102840_C_OfficialResults_cleaned_normalized.csv -> X:(133, 14), Y:(133, 4), U:(133, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102841_C_OfficialResults_cleaned_normalized.csv -> X:(145, 14), Y:(145, 4), U:(145, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102842_C_OfficialResults_cleaned_normalized.csv -> X:(140, 14), Y:(140, 4), U:(140, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102843_C_OfficialResults_cleaned_normalized.csv -> X:(137, 14), Y:(137, 4), U:(137, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102844_C_OfficialResults_cleaned_normalized.csv -> X:(129, 14), Y:(129, 4), U:(129, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102845_C_OfficialResults_cleaned_normalized.csv -> X:(106, 14), Y:(106, 4), U:(106, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102846_C_OfficialResults_cleaned_normalized.csv -> X:(123, 14), Y:(123, 4), U:(123, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102847_C_OfficialResults_cleaned_normalized.csv -> X:(138, 14), Y:(138, 4), U:(138, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102848_C_OfficialResults_cleaned_normalized.csv -> X:(137, 14), Y:(137, 4), U:(137, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102849_C_OfficialResults_cleaned_normalized.csv -> X:(125, 14), Y:(125, 4), U:(125, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102850_C_OfficialResults_cleaned_normalized.csv -> X:(123, 14), Y:(123, 4), U:(123, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102851_C_OfficialResults_cleaned_normalized.csv -> X:(124, 14), Y:(124, 4), U:(124, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102852_C_OfficialResults_cleaned_normalized.csv -> X:(131, 14), Y:(131, 4), U:(131, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102853_C_OfficialResults_cleaned_normalized.csv -> X:(116, 14), Y:(116, 4), U:(116, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102854_C_OfficialResults_cleaned_normalized.csv -> X:(140, 14), Y:(140, 4), U:(140, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102855_C_OfficialResults_cleaned_normalized.csv -> X:(136, 14), Y:(136, 4), U:(136, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102856_C_OfficialResults_cleaned_normalized.csv -> X:(131, 14), Y:(131, 4), U:(131, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102857_C_OfficialResults_cleaned_normalized.csv -> X:(128, 14), Y:(128, 4), U:(128, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102858_C_OfficialResults_cleaned_normalized.csv -> X:(123, 14), Y:(123, 4), U:(123, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102948_C_OfficialResults_cleaned_normalized.csv -> X:(126, 14), Y:(126, 4), U:(126, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103051_C_OfficialResults_cleaned_normalized.csv -> X:(123, 14), Y:(123, 4), U:(123, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103053_C_OfficialResults_cleaned_normalized.csv -> X:(99, 14), Y:(99, 4), U:(99, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103054_C_OfficialResults_cleaned_normalized.csv -> X:(120, 14), Y:(120, 4), U:(120, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-
 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103839_C_OfficialResults_cleaned_normalized.csv -> X:(135, 14), Y:(135, 4), U:(135, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103840_C_OfficialResults_cleaned_normalized.csv -> X:(138, 14), Y:(138, 4), U:(138, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103911_C_OfficialResults_cleaned_normalized.csv -> X:(151, 14), Y:(151, 4), U:(151, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103912_C_OfficialResults_cleaned_normalized.csv -> X:(160, 14), Y:(160, 4), U:(160, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103913_C_OfficialResults_cleaned_normalized.csv -> X:(157, 14), Y:(157, 4), U:(157, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103914_C_OfficialResults_cleaned_normalized.csv -> X:(140, 14), Y:(140, 4), U:(140, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103915_C_OfficialResults_cleaned_normalized.csv -> X:(148, 14), Y:(148, 4), U:(148, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103916_C_OfficialResults_cleaned_normalized.csv -> X:(151, 14), Y:(151, 4), U:(151, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103917_C_OfficialResults_cleaned_normalized.csv -> X:(148, 14), Y:(148, 4), U:(148, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103918_C_OfficialResults_cleaned_normalized.csv -> X:(125, 14), Y:(125, 4), U:(125, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103919_C_OfficialResults_cleaned_normalized.csv -> X:(145, 14), Y:(145, 4), U:(145, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103920_C_OfficialResults_cleaned_normalized.csv -> X:(149, 14), Y:(149, 4), U:(149, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103921_C_OfficialResults_cleaned_normalized.csv -> X:(133, 14), Y:(133, 4), U:(133, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103922_C_OfficialResults_cleaned_normalized.csv -> X:(154, 14), Y:(154, 4), U:(154, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103923_C_OfficialResults_cleaned_normalized.csv -> X:(149, 14), Y:(149, 4), U:(149, 20)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103924_C_OfficialResults_cleaned_normalized.csv -> X:(156, 14), Y:(156, 4), U:(156, 20)
#
# Combined dataset saved to C:\Users\vsi\Desktop\ijs\smucarski_skoki\project\simulation\2024_03_Planica_12_winds\cleaned\normalized\combined_dataset.npz

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
from scipy.interpolate import interp1d
import os
import matplotlib.pyplot as plt


def fit_ssm_cv(X_list, U_list, Y_list, n_splits, alpha=1e-3):
    """
    Fit an SSM model using K-fold cross-validation across jumps.
    Uses arc-length interpolation for error computation.
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42) 
        #razdeli na k skupin in jih k-1 uporab za treniranje
    train_errors, test_errors = [], []
    models = []
    is_nan = []


    for fold, (train_idx, test_idx) in enumerate(kf.split(X_list)):
        # --- build training data ---
        X_t = np.vstack([seq[:-1] for i, seq in enumerate(X_list) if i in train_idx])
        X_next = np.vstack([seq[1:] for i, seq in enumerate(X_list) if i in train_idx])
        U_t = np.vstack([u[:-1] for i, u in enumerate(U_list) if i in train_idx])
        Y_t = np.vstack([y[:-1] for i, y in enumerate(Y_list) if i in train_idx])

        # Regression [X_next] ~ [X_t | U_t]
        Phi = np.hstack([X_t, U_t])
        ridge = Ridge(alpha=alpha, fit_intercept=False)
        ridge.fit(Phi, X_next)
        Theta = ridge.coef_.T

        state_dim = X_t.shape[1]
        A = Theta[:state_dim, :].T
        B = Theta[state_dim:, :].T


        # Regression [Y_t] ~ [X_t | U_t]
        Phi_y = np.hstack([X_t, U_t])
        ridge_y = Ridge(alpha=alpha, fit_intercept=False)
        ridge_y.fit(Phi_y, Y_t)
        Theta_y = ridge_y.coef_.T

        obs_dim = Y_t.shape[1]
        C = Theta_y[:state_dim, :].T
        D = Theta_y[state_dim:, :].T

        models.append((A, B, C, D))

        # --- training error (shape-aligned) ---
        train_errs = []
        for i in train_idx:  #should be one, but just in case
            x0 = X_list[i][0]
            U_seq = U_list[i]
            X_seq = X_list[i]
            
            X_sim = [x0]
            for t in range(len(U_seq)-1):
                x_next = A @ X_sim[-1] + B @ U_seq[t]
                X_sim.append(x_next)
            X_sim = np.array(X_sim)
        
            train_err = error_fun(X_seq[:, :3], X_sim[:, :3])
            train_errs.append(train_err)

        train_errors.append(np.mean(train_errs))


        # --- test error ---
        test_errs = []
        for j in test_idx:
            x0 = X_list[j][0]
            U_seq = U_list[j]
            X_seq = X_list[j]

            # simulate with learned model
            X_sim = [x0]
            for t in range(len(U_seq) - 1):
                x_next = A @ X_sim[-1] + B @ U_seq[t]
                X_sim.append(x_next)
            X_sim = np.array(X_sim)

            # compute error
            test_err = error_fun(X_seq[:, :3], X_sim[:, :3])
            test_errs.append(test_err)

            # plot each trajectory
            plot(X_seq[:, :3], X_sim[:, :3], j, "12SSM2-2-angles", test_err)

        test_errors.append(np.mean(test_errs))

        print(np.mean(train_errs), np.mean(test_errs))
        is_nan.append(np.isnan(train_errors))

    return np.mean(train_errors), np.mean(test_errors), models, is_nan

# %%
avg_train_err, avg_test_err, models, is_nan = fit_ssm_cv(X_list, U_list, Y_list, n_splits=len(X_list), alpha=10)

print("average train error:", avg_train_err)
print("average test_error:", avg_test_err)
# Out:
# 1.5325464594113998 1.0048011748831303
# 1.5327227229538616 0.6594534954138596
# 1.5319847578290644 0.597296243516973
# 1.5294902489047562 1.2356637109197743
# 1.5327786748368804 0.5500649324801505
# 1.5324365225157568 1.6446754978588218
# 1.5270673571026692 1.5736478010516037
# 1.5319739605590452 1.3733416018961546
# 1.5353383716696405 0.4982417809024077
# 1.5320991180639985 0.8651129857662012
# 1.5316016255301246 1.1162555343326168
# 1.5330642831363337 1.4283309044582853
# 1.5223924341993913 2.932980400406171
# 1.5304087074767976 1.1565006719617095
# 1.527213939745882 1.749894220161484
# 1.5260308856974945 2.3368090680285127
# 1.5319909860536172 0.8569869699104912
# 1.5338378540094715 0.7583950349312817
# 1.5290600866996367 1.8027604853817274
# 1.5297244320590602 1.6764988268867753
# 1.5337917566824322 0.6564716714539036
# 1.527542357030761 2.523626344585122
# 1.5314092241891524 1.7380250202548042
# 1.529468200810836 1.58084414182382
# 1.5340111820091096 0.4463172605457624
# 1.526920957528618 2.22088818548343
# 1.5322914222785284 1.2549967020385346
# 1.5295404172061364 1.5297718974887675
# 1.5309169781811778 1.6135651358019818
# 1.5246627774031505 2.709008987510004
# 1.5267441670404869 2.038545981609022
# 1.523466425596666 2.791230121319324
# 1.5323624537052964 1.1712205270481102
# 1.524743045423413 2.6603211430525215
# 1.532178820555585 0.9806903795446942
# 1.5274335496910347 2.0432240075633623
# 1.533027438688873 0.7935552932360717
# 1.5297970848954625 2.439047997730495
# 1.5373328568719549 1.2479827045787353
# 1.5323574960993123 0.6608312512591493
# 1.5345717020335752 1.4270562574707424
# 1.5322618824121124 0.9563556305295821
# 1.5315562830464715 0.8788227114151658
# 1.534401872247691 0.8853104140061755
# 1.5301512016361427 1.3898668515652264
# 1.5319214627541462 0.8022775271556728
# 1.5296753749419723 0.81060256556611
# 1.5307491041588968 1.341724816098912
# 1.5205509125367798 3.4701089867913963
# 1.5311994996474474 1.2899637940931912
# 1.5357451788220995 0.9301412606772771
# 1.5225993309055648 2.2502421678631865
# 1.5307180148359432 1.9786828298877273
# average train error: 1.5295005602935814
# average test_error: 1.6521078008989911

# %% [markdown]
# ### fake quad

# %%
wind_features = ["Speed", "Tangent", "Cross", "Turbulence", "Speed_quad", "Tangent_quad", "Cross_quad", "Turbulence_quad"]

# %%
def preprocess_flight_normalized(df, step=0.05):
    """
    Preprocess a normalized flight dataframe (already interpolated) to generate states (X), observations (Y), and controls (U).
    
    Args:
        df (pd.DataFrame): Normalized flight dataframe (fixed time step).
        step (float): Time step between rows (used for derivatives).
        
    Returns:
        states (np.ndarray): State matrix [time_steps, state_dim].
        observations (np.ndarray): Observation matrix [time_steps, obs_dim].
        controls (np.ndarray): Control matrix [time_steps, control_dim].
    """

    df.columns = df.columns.str.strip()   #izloči imena stolpcev
    df = df.iloc[1:]
    
    df = df.ffill().bfill()   #back fill za manjkajoče vrednosti
    
    x = df["X [m]"].to_numpy()   #save values
    y = df["Y [m]"].to_numpy()
    z = df["Z [m]"].to_numpy()
    
    dt = step
    #vx = np.gradient(x, dt)   #gradient za hitrost
    vx = df.get("Speed hor. [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)
    vy = np.gradient(y, dt)
    #vz = np.gradient(z, dt)
    vz = df.get("Speed ver. [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)

    speed = df.get("speed resulting [km/h]", pd.Series([0]*len(x))).to_numpy() * (100/36)

    opening = df.get("Opening Angle [°]", pd.Series([0]*len(x))).to_numpy()
    roll_L = df.get("Roll Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    roll_R = df.get("Roll Angle Right [°]", pd.Series([0]*len(x))).to_numpy()
    yaw_L = df.get("Yaw Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    yaw_R = df.get("Yaw Angle Right [°]", pd.Series([0]*len(x))).to_numpy()
    stall_L = df.get("Stalling Angle Left [°]", pd.Series([0]*len(x))).to_numpy()
    stall_R = df.get("Stalling Angle Right [°]", pd.Series([0]*len(x))).to_numpy()

    states = np.stack([x, y, z, vx, vy, vz, speed, opening, roll_L, roll_R, yaw_L, yaw_R, stall_L, stall_R], axis=1)   #zgradimo state vector X

    height = df.get("Height above ground [m]", pd.Series([0]*len(x))).to_numpy()

    observations = np.stack([x, y, z, height], axis=1)   #zgradimo observation vector Y

    zone_feature_avgs = []
    values = []
    cols = []

    for feature in wind_features:
        for sensor_numb in range(12):
            sensor = f"W{sensor_numb + 1}"
            cols.append(f"{sensor}_{feature}")
            #print(cols)
    for col in cols:
        val = df.get(col, pd.Series([0]*len(x))).to_numpy() 
        values.append(val)
    
    controls = np.stack(values, axis=1)  # shape: (time_steps, 12)

    #for feature in wind_features:
    #    for zone, sensors in zones.items():
    #        cols = [f"{sensor}_{feature}" for sensor in sensors if f"{sensor}_{feature}" in df.columns]
    #        avg_feature = df[cols].mean(axis=1).to_numpy()
    #        zone_feature_avgs.append(avg_feature)
    #
    #controls = np.stack(zone_feature_avgs, axis=1)  # shape: (time_steps, 12)
    
    return states, observations, controls

# %%
import os
import pandas as pd
import numpy as np

normalized_folder = r'C:\Users\vsi\Desktop\ijs\smucarski_skoki\project\simulation\2024_03_Planica_12_winds\cleaned\cleaned_quad\normalized_quad'
combined_output = os.path.join(normalized_folder, "combined_dataset.npz")
file_names = []

X_list, Y_list, U_list = [], [], []

for filename in os.listdir(normalized_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(normalized_folder, filename)
        df = pd.read_csv(file_path)

        X_state, Y_obs, U_ctrl = preprocess_flight_normalized(df)

        X_list.append(X_state)
        Y_list.append(Y_obs)
        U_list.append(U_ctrl)
        file_names.append(filename)

        #if np.any(np.isnan(X_state)):
        #    print(f"NaN values in {filename}")

        print(f"Processed {filename} -> X:{X_state.shape}, Y:{Y_obs.shape}, U:{U_ctrl.shape}")

# Save combined dataset
#np.savez(combined_output, X=np.array(X_list, dtype=object), Y=np.array(Y_list, dtype=object), U=np.array(U_list, dtype=object))
print(f"\nCombined dataset saved to {combined_output}")
# Out:
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102625_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(133, 14), Y:(133, 4), U:(133, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102742_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(129, 14), Y:(129, 4), U:(129, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102831_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(142, 14), Y:(142, 4), U:(142, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102832_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(135, 14), Y:(135, 4), U:(135, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102833_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(132, 14), Y:(132, 4), U:(132, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102834_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(131, 14), Y:(131, 4), U:(131, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102835_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(153, 14), Y:(153, 4), U:(153, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102836_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(130, 14), Y:(130, 4), U:(130, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102837_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(120, 14), Y:(120, 4), U:(120, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102838_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(129, 14), Y:(129, 4), U:(129, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102839_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(142, 14), Y:(142, 4), U:(142, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102840_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(130, 14), Y:(130, 4), U:(130, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102841_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(142, 14), Y:(142, 4), U:(142, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102842_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(138, 14), Y:(138, 4), U:(138, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102843_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(135, 14), Y:(135, 4), U:(135, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102844_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(126, 14), Y:(126, 4), U:(126, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102845_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(103, 14), Y:(103, 4), U:(103, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102846_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(120, 14), Y:(120, 4), U:(120, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102847_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(137, 14), Y:(137, 4), U:(137, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102848_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(132, 14), Y:(132, 4), U:(132, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102849_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(122, 14), Y:(122, 4), U:(122, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102850_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(120, 14), Y:(120, 4), U:(120, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102851_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(123, 14), Y:(123, 4), U:(123, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102852_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(127, 14), Y:(127, 4), U:(127, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102853_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(114, 14), Y:(114, 4), U:(114, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102854_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(135, 14), Y:(135, 4), U:(135, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102855_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(132, 14), Y:(132, 4), U:(132, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102856_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(129, 14), Y:(129, 4), U:(129, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102857_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(124, 14), Y:(124, 4), U:(124, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102858_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(122, 14), Y:(122, 4), U:(122, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-102948_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(122, 14), Y:(122, 4), U:(122, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103051_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(120, 14), Y:(120, 4), U:(120, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103053_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(96, 14), Y:(96, 4), U:(96, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103054_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(117, 14), Y:(117, 4), U:(117, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103056_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(128, 14), Y:(128, 4), U:(128, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103059_C_Official_cleaned_quad-cleaned_normalized-quad.csv -> X:(117, 14), Y:(117, 4), U:(117, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-
C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(147, 14), Y:(147, 4), U:(147, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103912_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(156, 14), Y:(156, 4), U:(156, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103913_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(152, 14), Y:(152, 4), U:(152, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103914_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(136, 14), Y:(136, 4), U:(136, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103915_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(144, 14), Y:(144, 4), U:(144, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103916_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(147, 14), Y:(147, 4), U:(147, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103917_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(144, 14), Y:(144, 4), U:(144, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103918_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(121, 14), Y:(121, 4), U:(121, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103919_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(141, 14), Y:(141, 4), U:(141, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103920_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(146, 14), Y:(146, 4), U:(146, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103921_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(129, 14), Y:(129, 4), U:(129, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103922_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(150, 14), Y:(150, 4), U:(150, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103923_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(145, 14), Y:(145, 4), U:(145, 48)
# Processed 999_999_Jumper_Anon_ANO_1_20240409-103924_C_OfficialResults_cleaned_quad-cleaned_normalized-quad.csv -> X:(152, 14), Y:(152, 4), U:(152, 48)
#
# Combined dataset saved to C:\Users\vsi\Desktop\ijs\smucarski_skoki\project\simulation\2024_03_Planica_12_winds\cleaned\cleaned_quad\normalized_quad\combined_dataset.npz

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge

def fit_ssm_cv_quad(X_list, U_list, Y_list, n_splits=5, alpha=1e-3):
    """
    Fit an SSM model using K-fold cross-validation across jumps.

    Args:
        X_list, U_list, Y_list: lists of arrays (one per jump)
        n_splits (int): number of folds (or = len(X_list) for LOOCV)
        alpha (float): ridge regularization parameter

    Returns:
        avg_train_err, avg_test_err, models (list of (A,B,C,D) per fold)
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    train_errors, test_errors = [], []
    models = []

    for train_idx, test_idx in kf.split(X_list):
        # --- build training data ---
        X_t = np.vstack([seq[:-1] for i, seq in enumerate(X_list) if i in train_idx])
        X_next = np.vstack([seq[1:] for i, seq in enumerate(X_list) if i in train_idx])
        U_t = np.vstack([u[:-1] for i, u in enumerate(U_list) if i in train_idx])
        Y_t = np.vstack([y[:-1] for i, y in enumerate(Y_list) if i in train_idx])

        # Regression [X_next] ~ [X_t | U_t]
        Phi = np.hstack([X_t, U_t])
        ridge = Ridge(alpha=alpha, fit_intercept=False)     #ridge is just MNK z regularizacijo
                #
        ridge.fit(Phi, X_next)
        Theta = ridge.coef_.T

        state_dim = X_t.shape[1]
        control_dim = U_t.shape[1]
        A = Theta[:state_dim, :].T
        B = Theta[state_dim:, :].T

        # Regression [Y_t] ~ [X_t | U_t]
        Phi_y = np.hstack([X_t, U_t])
        ridge_y = Ridge(alpha=alpha, fit_intercept=False)
        ridge_y.fit(Phi_y, Y_t)
        Theta_y = ridge_y.coef_.T

        obs_dim = Y_t.shape[1]
        C = Theta_y[:state_dim, :].T
        D = Theta_y[state_dim:, :].T

        models.append((A, B, C, D))

        # --- training error (shape-aligned) ---
        train_errs = []
        for i in train_idx:
            x0 = X_list[i][0]
            U_seq = U_list[i]
            X_seq = X_list[i]
            
            X_sim = [x0]
            for t in range(len(U_seq)-1):
                x_next = A @ X_sim[-1] + B @ U_seq[t]
                X_sim.append(x_next)
            X_sim = np.array(X_sim)
        
            train_err = error_fun(X_seq[:, :3], X_sim[:, :3])
            train_errs.append(train_err)

        train_errors.append(np.mean(train_errs))

        # --- compute test error ---
        test_errs = []
        for j in test_idx:
            x0 = X_list[j][0]       #initial state...adjust it
            U_seq = U_list[j]
            X_seq = X_list[j]

            # simulate with learned model
            X_sim = [x0]
            for t in range(len(U_seq)-1):
                x_next = A @ X_sim[-1] + B @ U_seq[t]
                X_sim.append(x_next)
            X_sim = np.array(X_sim)

            ## compare to ground truth
            #test_err = np.mean(np.linalg.norm(X_seq[:, :3] - X_sim[:, :3], axis=1))
            ##test_err = penalized_bidirectional_distance(X_seq[::10], X_sim[::10])
            #test_errs.append(test_err)

            #plot(X_seq, X_sim, j, "SSM2-2-quad", test_err)
        test_errors.append(np.mean(test_errs))

        print(np.mean(train_errs), np.mean(test_errs))

    return np.mean(train_errors), np.mean(test_errors), models

# %%
avg_train_err, avg_test_err, models = fit_ssm_cv_quad(X_list, U_list, Y_list, n_splits=len(X_list), alpha=10)

print("average train error:", avg_train_err)
print("average test_error:", avg_test_err)
# Out:
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.667470894404978 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6712637473404668 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6631016367017912 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6702778342528601 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6725944024628883 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6650696779846057 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.663285435835357 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6720400419932964 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6712626051852009 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6720080454780906 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6605252177730974 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.670133440131967 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6600754957502328 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6678387401217178 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6650318160339628 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6661198232199068 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6707263412461357 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6688652886318396 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6695252087286319 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6666703253094806 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6664146283923322 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6666853865593716 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6721443555759439 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6667567668179832 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6680553277030485 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6595823909005665 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6643016552992278 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6615756672254258 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6608997846877245 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6611144500882504 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.664065565210074 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.670374646160092 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6597388263954864 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.660081800281346 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6634795318757674 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6675522426420872 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.670877605084346 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6713933508134322 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.667100748123485 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6669620796315774 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6618313721509772 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.670483696078424 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.665367323134494 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.667910493980669 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6689516564513485 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6617317292055642 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.665952847837662 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6687935355752743 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.662827872168233 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6722712280407432 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6676016205869049 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6713531554254204 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6667398849116652 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6689860725654782 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6690439938562507 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.664900995493724 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6686161175521241 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6718880279551585 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6666522264570809 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.6612660542879576 nan
# 1.6660172435294105 nan
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 avg_train_err, avg_test_err, models = fit_ssm_cv_quad(X_list, U_list, Y_list, n_splits=len(X_list), alpha=10)
#       3 print("average train error:", avg_train_err)
#       4 print("average test_error:", avg_test_err)
#
# Cell In[13], line 25, in fit_ssm_cv_quad(X_list, U_list, Y_list, n_splits, alpha)
#      23 X_t = np.vstack([seq[:-1] for i, seq in enumerate(X_list) if i in train_idx])
#      24 X_next = np.vstack([seq[1:] for i, seq in enumerate(X_list) if i in train_idx])
# ---> 25 U_t = np.vstack([u[:-1] for i, u in enumerate(U_list) if i in train_idx])
#      26 Y_t = np.vstack([y[:-1] for i, y in enumerate(Y_list) if i in train_idx])
#      28 # Regression [X_next] ~ [X_t | U_t]
#
# File c:\Users\vsi\Desktop\ijs\smucarski_skoki\project\flight_env\Lib\site-packages\numpy\_core\shape_base.py:292, in vstack(tup, dtype, casting)
#     290 if not isinstance(arrs, tuple):
#     291     arrs = (arrs,)
# --> 292 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:
